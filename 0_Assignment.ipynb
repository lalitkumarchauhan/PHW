# %% [markdown]
# ![image.png](attachment:cba4eaf5-ae1a-4057-aa14-34364d67cb70.png)

# %% [markdown]
# # Mr. Guido van Rossum

# %% [markdown]
# ![image.png](attachment:43927053-b63c-422d-8a38-a84c0550b25a.png)

# %% [markdown]
# # Object-oriented programming and structured programming

# %% [markdown]
# ![image.png](attachment:e340e393-60bf-4b6b-a8de-ec718d84c3d3.png)

# %% [markdown]
# # Yes, it considers uppercase and lowercase characters differently

# %% [markdown]
# ![image.png](attachment:ff1a9e53-5f5c-4e68-b696-6847a8be4d8d.png)

# %% [markdown]
# # .py

# %% [markdown]
# ![image.png](attachment:c7b2847d-7eda-45d4-ac60-5610fa3c9913.png)

# %% [markdown]
# # Python is an interpreted language, which means the source code of a Python program is converted into bytecode that is then executed by the Python virtual machine.

# %% [markdown]
# ![image.png](attachment:3379466e-89ff-490f-94ff-4f43e9dc6b87.png)

# %% [markdown]
# # A block is a piece of Python program text that is executed as a unit. The following are blocks: a module, a function body, and a class definition.

# %% [markdown]
# ![image.png](attachment:c065e08e-d6f7-40a2-8fae-f6ad1a879c8b.png)

# %% [markdown]
# # '#'

# %% [markdown]
# ![image.png](attachment:7f25e48a-7b81-43ee-b867-7799e4b9f924.png)

# %%
import sys
print(sys.version)
# Out:
# 3.10.8 | packaged by conda-forge | (main, Nov 22 2022, 08:26:04) [GCC 10.4.0]

# %% [markdown]
# ![image.png](attachment:048b8674-d5dd-4d0c-90d9-61ed6c36e927.png)

# %% [markdown]
# # lambda

# %% [markdown]
# ![image.png](attachment:ae378c7d-3a87-4b14-8e9a-9997092c406f.png)

# %% [markdown]
# # Preferred Installer Program

# %% [markdown]
# ![image.png](attachment:7fa6ca7a-830b-4db8-a980-a882aff8357b.png)

# %% [markdown]
# # def, class, import, print, type, bool, int, float, str

# %% [markdown]
# ![image.png](attachment:8d2f69cf-85ae-4203-a762-f7aa577bba4b.png)

# %% [markdown]
# # 79

# %% [markdown]
# ![image.png](attachment:f6de1099-13a8-4885-b08f-d5247aed8212.png)

# %% [markdown]
# # Python is a powerful, flexible, and easy-to-use high level language with english like programming dialect. Community support is also there.

# %% [markdown]
# ![image.png](attachment:22def7c0-1aa0-4375-a0f3-3e0449b30d3d.png)

# %% [markdown]
# #  Python uses the dynamic memory allocation which is managed by the Heap data structure.

# %% [markdown]
# ![image.png](attachment:b1211685-c194-4311-aeb8-3ce8727522f7.png)

# %% [markdown]
# Download latest python version for Windows from https://www.python.org/downloads/ and execute the installer and follow the prompts.
#
# To set the PATH variable:
# <ol>
#     <li>First, navigate to the Windows Environment Variables screen (where you can add/edit your paths)</li>
#     <li>Press the Windows Key + R on your keyboard in order to open the Run dialog box</li>
# <li>Type sysdm.cpl to open the System Properties</li>
# <li>Go to the Advanced tab and then click on the 'Environment Variable'</li>
# <li>That should take you to the Environment Variables screen, where you can add/edit your paths.</li>
# <li>Under the User variables box, click on 'New' to add the 'Path' variable (note that if your 'Path' variable already exists, then click on 'Edit' instead), You should then see the New User Variable box, where you may add/edit variables</li>
#     </ol>

# %% [markdown]
# ![image.png](attachment:3950cdf3-3664-4e17-a12e-965068f9683f.png)

# %% [markdown]
# # Yes, indentation is required in Python.
